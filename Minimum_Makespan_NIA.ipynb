# %%
# import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import os
data_collect = []
data_collect.append(pd.read_csv("Data1.csv"))
data_collect.append(pd.read_csv("Data2.csv")) 
data_collect.append(pd.read_csv("Data3.csv")) 
data_collect.append(pd.read_csv("Data4.csv")) 

data = pd.concat(data_collect, ignore_index=True)

# %% [markdown]
# Benchmark1 - Population_Size

# %%
sns.violinplot(data = data, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.boxplot(data = data, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark1 - Pool_Size

# %%
data_collect2 = []
data_collect2.append(pd.read_csv("Data5.csv"))
data_collect2.append(pd.read_csv("Data6.csv")) 
data_collect2.append(pd.read_csv("Data7.csv")) 
data_collect2.append(pd.read_csv("Data8.csv")) 

data2 = pd.concat(data_collect2, ignore_index=True)

# %%
sns.violinplot(data = data2, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data2, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark1 - Mutation_Rate

# %%
data_collect3 = []
data_collect3.append(pd.read_csv("Data9.csv"))
data_collect3.append(pd.read_csv("Data10.csv")) 
data_collect3.append(pd.read_csv("Data11.csv")) 
data_collect3.append(pd.read_csv("Data12.csv")) 

data3 = pd.concat(data_collect3, ignore_index=True)

# %%
sns.violinplot(data = data3, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data3, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark1 - Time_Limit

# %%
data_collect4 = []
data_collect4.append(pd.read_csv("Data13.csv"))
data_collect4.append(pd.read_csv("Data14.csv")) 
data_collect4.append(pd.read_csv("Data15.csv")) 
data_collect4.append(pd.read_csv("Data16.csv")) 

data4 = pd.concat(data_collect4, ignore_index=True)

# %%
sns.violinplot(data = data4, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data4, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark2 - population_size

# %%
data_collect5 = []
data_collect5.append(pd.read_csv("data17.csv"))
data_collect5.append(pd.read_csv("data18.csv")) 
data_collect5.append(pd.read_csv("data19.csv")) 
data_collect5.append(pd.read_csv("data20.csv")) 

data5 = pd.concat(data_collect5, ignore_index=True)

# %%
sns.violinplot(data = data5, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data5, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark2 - pool_size

# %%
data_collect6 = []
data_collect6.append(pd.read_csv("data21.csv"))
data_collect6.append(pd.read_csv("data22.csv")) 
data_collect6.append(pd.read_csv("data23.csv")) 
data_collect6.append(pd.read_csv("data24.csv")) 

data6 = pd.concat(data_collect6, ignore_index=True)

# %%
sns.violinplot(data = data6, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data6, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark2 - mutation_rate

# %%
data_collect7 = []
data_collect7.append(pd.read_csv("data25.csv"))
data_collect7.append(pd.read_csv("data26.csv")) 
data_collect7.append(pd.read_csv("data27.csv")) 
data_collect7.append(pd.read_csv("data28.csv")) 

data7 = pd.concat(data_collect7, ignore_index=True)

# %%
sns.violinplot(data = data7, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data7, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark2 - time_limit

# %%
data_collect8 = []
data_collect8.append(pd.read_csv("data29.csv"))
data_collect8.append(pd.read_csv("data30.csv")) 
data_collect8.append(pd.read_csv("data31.csv")) 
data_collect8.append(pd.read_csv("data32.csv")) 

data8 = pd.concat(data_collect8, ignore_index=True)

# %%
sns.violinplot(data = data8, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data8, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark3 - population_size

# %%
data_collect9 = []
data_collect9.append(pd.read_csv("data33.csv"))
data_collect9.append(pd.read_csv("data34.csv")) 
data_collect9.append(pd.read_csv("data35.csv")) 
data_collect9.append(pd.read_csv("data36.csv")) 

data9 = pd.concat(data_collect9, ignore_index=True)

# %%
sns.violinplot(data = data9, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data9, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark3 - pool_size

# %%
data_collect10 = []
data_collect10.append(pd.read_csv("data37.csv"))
data_collect10.append(pd.read_csv("data38.csv")) 
data_collect10.append(pd.read_csv("data39.csv")) 
data_collect10.append(pd.read_csv("data40.csv")) 

data10 = pd.concat(data_collect10, ignore_index=True)

# %%
sns.violinplot(data = data10, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data10, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark3 - mutation_prob

# %%
data_collect11 = []
data_collect11.append(pd.read_csv("data41.csv"))
data_collect11.append(pd.read_csv("data42.csv")) 
data_collect11.append(pd.read_csv("data43.csv")) 
data_collect11.append(pd.read_csv("data44.csv")) 

data11 = pd.concat(data_collect11, ignore_index=True)

# %%
sns.violinplot(data = data11, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data11, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark3 - time_limit

# %%
data_collect12 = []
data_collect12.append(pd.read_csv("data45.csv"))
data_collect12.append(pd.read_csv("data46.csv")) 
data_collect12.append(pd.read_csv("data47.csv")) 
data_collect12.append(pd.read_csv("data48.csv")) 

data12 = pd.concat(data_collect12, ignore_index=True)

# %%
sns.violinplot(data = data12, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data12, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()
