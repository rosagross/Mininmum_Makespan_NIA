# %%
# import libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import os
data_collect = []
data_collect.append(pd.read_csv("Data1.csv"))
data_collect.append(pd.read_csv("Data2.csv")) 
data_collect.append(pd.read_csv("Data3.csv")) 
data_collect.append(pd.read_csv("Data4.csv")) 

data = pd.concat(data_collect, ignore_index=True)

# %% [markdown]
# Benchmark1 - Population_Size

# %%
sns.violinplot(data = data, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.boxplot(data = data, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
Benchmark1 - Pool_Size

# %%
data_collect2 = []
data_collect2.append(pd.read_csv("Data5.csv"))
data_collect2.append(pd.read_csv("Data6.csv")) 
data_collect2.append(pd.read_csv("Data7.csv")) 
data_collect2.append(pd.read_csv("Data8.csv")) 

data2 = pd.concat(data_collect2, ignore_index=True)

# %%
sns.violinplot(data = data2, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data2, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark1 - Mutation_Rate

# %%
data_collect3 = []
data_collect3.append(pd.read_csv("Data9.csv"))
data_collect3.append(pd.read_csv("Data10.csv")) 
data_collect3.append(pd.read_csv("Data11.csv")) 
data_collect3.append(pd.read_csv("Data12.csv")) 

data3 = pd.concat(data_collect3, ignore_index=True)

# %%
sns.violinplot(data = data3, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %%
sns.violinplot(data = data2, 
               x = "Changing Parameter", y='Time per Iteration', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()

# %% [markdown]
# Benchmark1 - Time_Limit

# %%
data_collect4 = []
data_collect4.append(pd.read_csv("Data13.csv"))
data_collect4.append(pd.read_csv("Data14.csv")) 
data_collect4.append(pd.read_csv("Data15.csv")) 
data_collect4.append(pd.read_csv("Data16.csv")) 

data4 = pd.concat(data_collect3, ignore_index=True)

print(data4)
# Out:
#     Algorithm Type Changing Parameter   Time  Iterations  Time per Iteration  \
# 0           Random  mutation_prob 30%  478.0         1.0          478.000000
# 1           Random  mutation_prob 30%  327.0         4.0           81.750000
# 2           Random  mutation_prob 30%  322.0         5.0           64.400000
# 3           Random  mutation_prob 30%  324.0         6.0           54.000000
# 4           Random  mutation_prob 30%  348.0         7.0           49.714286
# 5           Random  mutation_prob 30%  342.0         7.0           48.857143
# 6           Random  mutation_prob 30%  321.0         8.0           40.125000
# 7           Random  mutation_prob 30%  321.0         8.0           40.125000
# 8           Random  mutation_prob 30%  337.0         8.0           42.125000
# 9           Random  mutation_prob 30%  303.0         7.0           43.285714
# 10          Random  mutation_prob 30%  326.0         8.0           40.750000
# 11          Random  mutation_prob 30%  332.0         8.0           41.500000
# 12          Random  mutation_prob 30%  334.0         8.0           41.750000
# 13          Random  mutation_prob 30%  309.0         7.0           44.142857
# 14          Random  mutation_prob 30%  335.0         8.0           41.875000
# 15          Random  mutation_prob 30%  333.0         8.0           41.625000
# 16          Random  mutation_prob 30%  305.0         7.0           43.571429
# 17          Random  mutation_prob 30%  342.0         8.0           42.750000
# 18          Random  mutation_prob 30%  331.0         8.0           41.375000
# 19          Random  mutation_prob 30%  325.0         8.0           40.625000
# 20          Random  mutation_prob 30%  331.0         8.0           41.375000
# 21          Random  mutation_prob 30%  332.0         8.0           41.500000
# 22          Random  mutation_prob 30%  330.0         8.0           41.250000
# 23          Random  mutation_prob 30%  334.0         8.0           41.750000
# 24          Random  mutation_prob 30%  306.0         7.0           43.714286
# 25          Random  mutation_prob 30%  324.0         8.0           40.500000
# 26          Random  mutation_prob 30%  332.0         8.0           41.500000
# 27          Random  mutation_prob 30%  326.0         8.0           40.750000
# 28          Random  mutation_prob 30%  332.0         8.0           41.500000
# 29          Random  mutation_prob 30%  336.0         8.0           42.000000
# ..             ...                ...    ...         ...                 ...
# 370       Improved  mutation_prob 70%  334.0         6.0           55.666667
# 371       Improved  mutation_prob 70%  323.0         6.0           53.833333
# 372       Improved  mutation_prob 70%  336.0         6.0           56.000000
# 373       Improved  mutation_prob 70%  327.0         6.0           54.500000
# 374       Improved  mutation_prob 70%  331.0         6.0           55.166667
# 375       Improved  mutation_prob 70%  332.0         6.0           55.333333
# 376       Improved  mutation_prob 70%  328.0         6.0           54.666667
# 377       Improved  mutation_prob 70%  333.0         6.0           55.500000
# 378       Improved  mutation_prob 70%  336.0         6.0           56.000000
# 379       Improved  mutation_prob 70%  329.0         6.0           54.833333
# 380       Improved  mutation_prob 70%  328.0         6.0           54.666667
# 381       Improved  mutation_prob 70%  326.0         6.0           54.333333
# 382       Improved  mutation_prob 70%  343.0         6.0           57.166667
# 383       Improved  mutation_prob 70%  340.0         6.0           56.666667
# 384       Improved  mutation_prob 70%  325.0         6.0           54.166667
# 385       Improved  mutation_prob 70%  341.0         6.0           56.833333
# 386       Improved  mutation_prob 70%  332.0         6.0           55.333333
# 387       Improved  mutation_prob 70%  339.0         6.0           56.500000
# 388       Improved  mutation_prob 70%  341.0         6.0           56.833333
# 389       Improved  mutation_prob 70%  337.0         6.0           56.166667
# 390       Improved  mutation_prob 70%  330.0         6.0           55.000000
# 391       Improved  mutation_prob 70%  337.0         6.0           56.166667
# 392       Improved  mutation_prob 70%  338.0         6.0           56.333333
# 393       Improved  mutation_prob 70%  328.0         6.0           54.666667
# 394       Improved  mutation_prob 70%  337.0         6.0           56.166667
# 395       Improved  mutation_prob 70%  336.0         6.0           56.000000
# 396       Improved  mutation_prob 70%  328.0         6.0           54.666667
# 397       Improved  mutation_prob 70%  335.0         6.0           55.833333
# 398       Improved  mutation_prob 70%  335.0         6.0           55.833333
# 399       Improved  mutation_prob 70%  326.0         6.0           54.333333
#
#       Value
# 0    7738.0
# 1    8079.0
# 2    7664.0
# 3    7734.0
# 4    7454.0
# 5    7613.0
# 6    7637.0
# 7    7662.0
# 8    7441.0
# 9    7815.0
# 10   7878.0
# 11   7632.0
# 12   7279.0
# 13   8019.0
# 14   7755.0
# 15   7480.0
# 16   7616.0
# 17   7596.0
# 18   7301.0
# 19   7476.0
# 20   7779.0
# 21   7546.0
# 22   7991.0
# 23   7932.0
# 24   7487.0
# 25   7854.0
# 26   7688.0
# 27   7305.0
# 28   7386.0
# 29   7456.0
# ..      ...
# 370  7079.0
# 371  7163.0
# 372  6930.0
# 373  7440.0
# 374  7035.0
# 375  7173.0
# 376  7174.0
# 377  7041.0
# 378  6875.0
# 379  6993.0
# 380  7218.0
# 381  7382.0
# 382  7225.0
# 383  7302.0
# 384  7429.0
# 385  7044.0
# 386  7270.0
# 387  7058.0
# 388  7139.0
# 389  7289.0
# 390  7474.0
# 391  7080.0
# 392  7494.0
# 393  7213.0
# 394  7050.0
# 395  7028.0
# 396  7015.0
# 397  7266.0
# 398  7167.0
# 399  6859.0
#
# [400 rows x 6 columns]

# %%
sns.violinplot(data = data4, 
               x = "Changing Parameter", y='Value', 
               hue = "Algorithm Type", split = True, inner = "box", palette = ['b','r'])
plt.legend(loc='upper center')
plt.tight_layout()
